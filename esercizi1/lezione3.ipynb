# %% [markdown]
# # Pandas
# Lavoriamo con set di dati tipo R
# Tipi di dati sono: Series -> colonna di un foglio di calcolo, Dataframe -> ...

# %%
# %conda install pandas
import pandas as pd
# Out:
# 2 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.1.1
#     latest version: 26.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# Creating a Series from a list
data = [10, 20, 30, 40, 50]
# la serie può essere indicizzata
series = pd.Series(data, index=['a', 'b', 'c', 'd', 'e'])
# cosi vedo la serie
series
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
# ma posso anche vedere solo gli indici
series.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='str')

# %%
# se voglio recuperare i dati come un array numpy, mi basta fare
series.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
# Dataframe 
data = {
    'job_title': ['Data Analyst', 'Data Scientist', 'Data Engineer',],
    'location': ['Italy', 'USA', 'Germany'],
    'salary': [40000, 80000, 70000],
    'date_posted': ['2024-12-01', '2024-11-15', '2024-12-10']  # formato YYYY-MM-DD
}

df = pd.DataFrame(data)
df
# Out:
#         job_title location  salary date_posted
# 0    Data Analyst    Italy   40000  2024-12-01
# 1  Data Scientist      USA   80000  2024-11-15
# 2   Data Engineer  Germany   70000  2024-12-10

# %%
# Posso selezionare singole colonne
df['job_title'] # posso anche usare questo a mo di metodo df.job_title
# Out:
# 0      Data Analyst
# 1    Data Scientist
# 2     Data Engineer
# Name: job_title, dtype: str

# %%
# ogni colonna è in verità solo una series
type(df['job_title'])
# Out:
# pandas.Series

# %%
#guardo le colonne
df.columns
# Out:
# Index(['job_title', 'location', 'salary', 'date_posted'], dtype='str')

# %%
# Access a row by index, accedo per indirizzo
df.job_title[2]
# Out:
# 'Data Engineer'

# %% [markdown]
# Caricamento dei Dati
#
# Possiamo caricare dati da un file CSV utilizzando pd.read_csv()
# Possiamo anche caricare dati da un file Excel utilizzando pd.read_excel()

# %% [markdown]
# Ci sono vari modi per caricare ed usare un dataset, alla fine pero di deve convertirlo in pandas con **df = dataset['train'].to_pandas()**

# %% [markdown]
# il comando .info() ci da informazioni sul numero totale di elementi, di colonne, il nome delle colonne, gli elementi non nulli per colonna e il tipo di dato

# %% [markdown]
# df.describe() mi da statistiche sulle colonne numeriche

# %% [markdown]
# Ma esistono anche altri modi per ottenere una panoramica del DataFrame, come:
#
# len(df) - Ottiene la lunghezza del DataFrame (numero di righe).
#
# df.shape - Restituisce una tupla con il numero di righe e colonne (righe, colonne).
#
# df.index - Descrive l'indice del DataFrame.
#
# df.columns - Elenca i nomi delle colonne del DataFrame.
#
# df.count() - Conta il numero di valori non nulli per ogni colonna.
#
# df['column_name'].unique() - Restituisce i valori distinti presenti in una colonna.

# %% [markdown]
# Filtrare le Righe
#
# Puoi filtrare le righe applicando una condizione all'interno delle parentesi quadre [].
# La sintassi è: df[df['column_name'] > valore].
# L'operatore > può essere sostituito con qualsiasi altro operatore condizionale, come: >, <, ==, !=, ecc.
