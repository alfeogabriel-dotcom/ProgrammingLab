# %% [markdown]
# Questo è testo markdown

# %%
print("ciao")
1+1
# Out:
# ciao
# 2

# %% [markdown]
# # Prova
# **non ho ben capito tutto, perché devo eseguirlo prima che venga scritto????**

# %% [markdown]
# forse mi è un po' più chiaro, cmq fa abbastanza schifo *fr fr*

# %%
# %timeit [n*n for n in range(200)]
# Out:
# 2.43 μs ± 17.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# > cosa fa sta roba?
# - questa
# - è
# - una
# - lista
#
# 'fa qulcosa questo
# print(ciao)'
# ----

# %%
import numpy as np
a = np.array([1,2,3,4,None])

a
# Out:
# array([1, 2, 3, 4, None], dtype=object)
